# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#taking only SPZ whitch gives better results


res16_20 = pd.read_csv('../ResultsEvaluation/results_evaluation_genus_paired20.csv', sep='\t')
temp = res16_20[res16_20['Classifier'].str.contains('SPZ')]
res16_20 = temp

res16_40 = pd.read_csv('../ResultsEvaluation/results_evaluation_genus_40_paired.csv', sep='\t')
temp = res16_40[res16_40['Classifier'].str.contains('SPZ')]
res16_40 = temp

res30_40 = pd.read_csv('../ResultsEvaluation/results_evaluation_genus_30_40.csv', sep='\t')
temp = res30_40[res30_40['Classifier'].str.contains('SPZ')]
res30_40 = temp

res40_40 = pd.read_csv('../ResultsEvaluation/results_evaluation_genus40_40.csv', sep='\t')
temp = res40_40[res40_40['Classifier'].str.contains('SPZ')]
res40_40 = temp

res40_50 = pd.read_csv('../ResultsEvaluation/results_evaluation_genus40_50.csv', sep='\t')
temp = res40_50[res40_50['Classifier'].str.contains('SPZ')]
res40_50 = temp

res40_60 = pd.read_csv('../ResultsEvaluation/results_evaluation_genus40_50.csv', sep='\t')
temp = res40_60[res40_60['Classifier'].str.contains('SPZ')]
res40_60 = temp

res50_40 = pd.read_csv('../ResultsEvaluation/results_evaluation_genus50_40.csv', sep='\t')
temp = res50_40[res50_40['Classifier'].str.contains('SPZ')]
res50_40 = temp

res50_60 = pd.read_csv('../ResultsEvaluation/results_evaluation_genus50_60.csv', sep='\t')
temp = res50_60[res50_60['Classifier'].str.contains('SPZ')]
res50_60 = temp

# %%
res16_40
# Out:
#                            Classifier       tp      fp      fn     ok  no  \
# 10     strex_centrifuge_25000_SPZ.res  2969555   99179   23233  33033   0
# 15    strex_clark_genus_25000_SPZ.res  2988588   96774   39638      0   0
# 20  strex_clark_species_25000_SPZ.res  2883374  140628  100998      0   0
# 25        strex_kraken1_25000_SPZ.res  3029640   23179   33842  38339   0
# 30        strex_kraken2_25000_SPZ.res  3030485   30916   24245  39354   0
#
#     (tp+fp+fn+ok+no)      sens      prec        f1   pearson
# 10           3125000  0.950258  0.967681  0.958890  0.987683
# 15           3125000  0.956348  0.968634  0.962452  0.998729
# 20           3125000  0.922680  0.953496  0.937835  0.995330
# 25           3125000  0.969485  0.992407  0.980812  0.996646
# 30           3125000  0.969755  0.989901  0.979725  0.996681

# %%
l =['centrifuge','genus','kraken1','kraken2']
sens = {}
prec = {}
pearson = {}
for name in (l):
    temp1 = []
    temp2 = []
    temp3 = []
    temp1.append(res16_20[res16_20['Classifier'].str.contains(name)]['sens'].values[0])
    temp2.append(res16_20[res16_20['Classifier'].str.contains(name)]['prec'].values[0])
    temp3.append(res16_20[res16_20['Classifier'].str.contains(name)]['pearson'].values[0])
    
    temp1.append(res16_40[res16_40['Classifier'].str.contains(name)]['sens'].values[0])
    temp2.append(res16_40[res16_40['Classifier'].str.contains(name)]['prec'].values[0])
    temp3.append(res16_40[res16_40['Classifier'].str.contains(name)]['pearson'].values[0])
    
    temp1.append(res30_40[res30_40['Classifier'].str.contains(name)]['sens'].values[0])
    temp2.append(res30_40[res30_40['Classifier'].str.contains(name)]['prec'].values[0])
    temp3.append(res30_40[res30_40['Classifier'].str.contains(name)]['pearson'].values[0])
    
    temp1.append(res40_40[res40_40['Classifier'].str.contains(name)]['sens'].values[0])
    temp2.append(res40_40[res40_40['Classifier'].str.contains(name)]['prec'].values[0])
    temp3.append(res40_40[res40_40['Classifier'].str.contains(name)]['pearson'].values[0])
    
    temp1.append(res40_50[res40_50['Classifier'].str.contains(name)]['sens'].values[0])
    temp2.append(res40_50[res40_50['Classifier'].str.contains(name)]['prec'].values[0])
    temp3.append(res40_50[res40_50['Classifier'].str.contains(name)]['pearson'].values[0])
    
    temp1.append(res40_60[res40_60['Classifier'].str.contains(name)]['sens'].values[0])
    temp2.append(res40_60[res40_60['Classifier'].str.contains(name)]['prec'].values[0])
    temp3.append(res40_60[res40_60['Classifier'].str.contains(name)]['pearson'].values[0])
    
    temp1.append(res50_40[res50_40['Classifier'].str.contains(name)]['sens'].values[0])
    temp2.append(res50_40[res50_40['Classifier'].str.contains(name)]['prec'].values[0])
    temp3.append(res50_40[res50_40['Classifier'].str.contains(name)]['pearson'].values[0])
    
    temp1.append(res50_60[res50_60['Classifier'].str.contains(name)]['sens'].values[0])
    temp2.append(res50_60[res50_60['Classifier'].str.contains(name)]['prec'].values[0])
    temp3.append(res50_60[res50_60['Classifier'].str.contains(name)]['pearson'].values[0])
    
    sens[name] = temp1
    prec[name] = temp2
    pearson[name] = temp3

# %%
sens
# Out:
# {'centrifuge': [0.928959,
#   0.950258,
#   0.948413,
#   0.9453010000000001,
#   0.9414680000000001,
#   0.9414680000000001,
#   0.9402809999999999,
#   0.9295950000000001],
#  'genus': [0.9312879999999999,
#   0.956348,
#   0.953234,
#   0.9469799999999999,
#   0.9406530000000001,
#   0.9406530000000001,
#   0.938832,
#   0.9229149999999999],
#  'kraken1': [0.9476559999999999,
#   0.969485,
#   0.966858,
#   0.9629030000000001,
#   0.9585319999999999,
#   0.9585319999999999,
#   0.9373790000000001,
#   0.925731],
#  'kraken2': [0.9490190000000001,
#   0.9697549999999999,
#   0.968326,
#   0.9653450000000001,
#   0.961692,
#   0.961692,
#   0.960425,
#   0.948544]}

# %%
prec
# Out:
# {'centrifuge': [0.9434790000000001,
#   0.9676809999999999,
#   0.97034,
#   0.971412,
#   0.9721069999999999,
#   0.9721069999999999,
#   0.972576,
#   0.97603],
#  'genus': [0.939227,
#   0.968634,
#   0.973643,
#   0.9746549999999999,
#   0.9752,
#   0.9752,
#   0.975506,
#   0.987339],
#  'kraken1': [0.9668770000000001,
#   0.9924069999999999,
#   0.9952719999999999,
#   0.9960319999999999,
#   0.996217,
#   0.996217,
#   0.975822,
#   0.978144],
#  'kraken2': [0.966089,
#   0.989901,
#   0.992813,
#   0.993757,
#   0.994324,
#   0.994324,
#   0.994409,
#   0.9949959999999999]}

# %%
pearson
# Out:
# {'centrifuge': [0.9797319999999999,
#   0.987683,
#   0.9874930000000001,
#   0.9872479999999999,
#   0.9870450000000001,
#   0.9870450000000001,
#   0.987017,
#   0.9866530000000001],
#  'genus': [0.989136,
#   0.9987290000000001,
#   0.998181,
#   0.9972559999999999,
#   0.9963139999999999,
#   0.9963139999999999,
#   0.9961690000000001,
#   0.994892],
#  'kraken1': [0.988059,
#   0.9966459999999999,
#   0.9962290000000001,
#   0.995891,
#   0.995592,
#   0.995592,
#   0.9854649999999999,
#   0.9850040000000001],
#  'kraken2': [0.9891209999999999,
#   0.9966809999999999,
#   0.9964649999999999,
#   0.9963280000000001,
#   0.996199,
#   0.996199,
#   0.996189,
#   0.995849]}
